# %% [markdown]
# Notable neurons
# - elmo4096 192, seems to activate on articles
# - openai_transformer_-1, neuron  536 punctuation
# - bert_base_cased_-1, neuron  304 end of sentence
# - xlnet_large_cased_-1, neuron  601 NP's. Seems to light up at numbers.
# - calypso_transformer_6_512_base_-1, neuron  975 verbs

# %%
import json
import h5py
import torch
import numpy as np
from IPython.display import HTML
import matplotlib.pyplot as plt
import pickle

# %%
np.random.seed(0)

# %%
method_l = [
    "maxcorr", 
    "mincorr", 
    "maxlinreg", 
    "minlinreg", 
    "cca", 
    "lincka", 
    # "rbfcka",
]

# %%
# Set `res_d`, `network_l`, `num_neurons_d`
base = "/data/sls/temp/johnmwu/contextual-corr-analysis/results1_"
res_fname = {method : base + method for method in 
                method_l}

res_d = {}
for method in method_l:
    with open(res_fname[method], 'rb') as f:
        res_d[method] = pickle.load(f)

network_l = [network for network in res_d["maxcorr"]["corrs"]]

num_neurons_d = {}
for network in network_l:
    num_neurons_d[network] = len(next(iter(res_d["maxcorr"]["corrs"][network].values()))) # god this is a hack

# %%
def network2mname(network):
    i = network.rfind('_') 
    return network[:i]

# %%
def network2fname(network):
    i = network.rfind('_')
    network = network[:i]
    return "/data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/{0}/ptb_pos_dev.hdf5".format(network)

# %%
# set `h5_d` : {network: h5} and `sentence_d`
h5_d = {}
for network in network_l:
    h5_d[network] = h5py.File(network2fname(network), 'r')

sentence_d = json.loads(h5_d[network_l[0]]['sentence_to_index'][0]) # "sentence dict": {sentence, str ix}
temp = {}
for k, v in sentence_d.items():
    temp[v] = k
sentence_d = temp # now {str ix, sentence}

# %%
# set stats
# `means_d`, `stdevs_d`, `max_d`, `min_d`
fname = "/data/sls/temp/johnmwu/contextual-corr-analysis/stats"
with open(fname, "rb") as f:
    d = pickle.load(f)
    means_d = d["mean"]
    stdevs_d = d["std"]
    max_d = d["max"]
    min_d = d["min"]

# %%
# set `neuron_sorts`
rk_methods = {"maxcorr", "mincorr", "maxlinreg", "minlinreg"}
neuron_sorts = {network: {} for network in network_l}
for network in network_l:
    for method in rk_methods:
        neuron_sorts[network][method] = res_d[method]["neuron_sort"][network]

# %% [markdown]
# # Visualizations

# %%
s_ix_l = [str(i) for i in range(1000, 1010)] # "sentence index"
method = "mincorr"
layer = -1
cmap = plt.get_cmap('bwr')

# %%
def maxmin_normalize(a, maximum, minimum):
    maxabs = max([abs(maximum), abs(minimum)])
    return .5 + a/maxabs

# %%
def meanstd_normalize(a, mean, stdev):
    return torch.sigmoid((a-mean) / stdev)

# %%
def visualize_neuron(network, method=None, rank=0, neuron_ix=None, s_ix_l=list(range(10))):    
    if neuron_ix is None:
        neuron_ix = neuron_sorts[network][method][rank]
    
    # Stats
    a = network2mname(network)
    mean = means_d[a][layer, neuron_ix].item()
    stdev = stdevs_d[a][layer, neuron_ix].item()
    maximum = max_d[a][layer, neuron_ix].item()
    minimum = min_d[a][layer, neuron_ix].item()

    # Set `html_str_l`
    html_str_l = []
    for s_ix in s_ix_l:
        # Set `representations`
        representations = torch.tensor(h5_d[network][s_ix])
        representations = representations[layer] if representations.dim() == 3 else representations

        # Set `activations_mod`
        a = network2mname(network)
        mean = means_d[a][layer, neuron_ix].item()
        stdev = stdevs_d[a][layer, neuron_ix].item()
        maximum = max_d[a][layer, neuron_ix].item()
        minimum = min_d[a][layer, neuron_ix].item()

        activations = representations[:, neuron_ix]
        # activations_mod = meanstd_normalize(activations, mean, stdev)
        activations_mod = maxmin_normalize(activations, maximum, minimum)
        
        # Update `html_str_l`
        html_str_l.append('Sentence index: {0}<br>'.format(s_ix))
        sentence = sentence_d[s_ix].split(' ')
        for act, tok in zip(activations_mod, sentence):
            # Set `color_str`
            act = float(act)
            r, g, b, a = cmap(act)
            red_str = '{0:02x}'.format(int(255.9*r)) # should be 256, but can't. Some vals became 1. 
            green_str = '{0:02x}'.format(int(255.9*g))
            blue_str = '{0:02x}'.format(int(255.9*b))

            color_str = red_str + green_str + blue_str

            html_str_l.append('<span style="background-color:#{0}">{1} </span>'.format(color_str, tok))
        html_str_l.append('<br><br>')
    
    # display
    print("Network: {0}, neuron {1:4d}".format(network, neuron_ix))
    display(HTML('<code>' + ''.join(html_str_l) + '</code>'))

# %%
s_ix_l=[str(i) for i in np.random.choice(5512, (10,))]
for network in network_l:
    visualize_neuron(network, "maxcorr", s_ix_l=s_ix_l)
# Out:
# Network: bert_large_cased_-1, neuron  245
# <code>Sentence index: 255<br><span style="background-color:#0000ff">Also </span><span style="background-color:#ff6060">, </span><span style="background-color:#ffcaca">Richard </span><span style="background-color:#ff4c4c">A. </span><span style="background-color:#ffe2e2">Barkley </span><span style="background-color:#ff4040">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff9898">former </span><span style="background-color:#ffeeee">marketing </span><span style="background-color:#ff7070">executive </span><span style="background-color:#ff9494">with </span><span style="background-color:#ffc8c8">FMC </span><span style="background-color:#fefeff">Corp. </span><span style="background-color:#ffe4e4">, </span><span style="background-color:#ff3c3c">was </span><span style="background-color:#ffb6b6">appointed </span><span style="background-color:#ff7a7a">president </span><span style="background-color:#ff8c8c">of </span><span style="background-color:#fff6f6">Continental </span><span style="background-color:#fff6f6">Container </span><span style="background-color:#ffc8c8">Systems </span><span style="background-color:#ff6a6a">, </span><span style="background-color:#ff6a6a">a </span><span style="background-color:#ffaeae">producer </span><span style="background-color:#ffacac">of </span><span style="background-color:#a0a0ff">can </span><span style="background-color:#d0d0ff">closing </span><span style="background-color:#e4e4ff">machinery </span><span style="background-color:#ff9c9c">that </span><span style="background-color:#ff8a8a">Figgie </span><span style="background-color:#ffb2b2">acquired </span><span style="background-color:#ff8e8e">late </span><span style="background-color:#ffc6c6">last </span><span style="background-color:#ff6666">year </span><span style="background-color:#fff4f4">. </span><br><br>Sentence index: 3097<br><span style="background-color:#0000ff">Perhaps </span><span style="background-color:#ff3434">the </span><span style="background-color:#ff9e9e">biggest </span><span style="background-color:#ff7474">of </span><span style="background-color:#ff8888">those </span><span style="background-color:#ff5656">factors </span><span style="background-color:#ff5252">is </span><span style="background-color:#ff9e9e">its </span><span style="background-color:#ffacac">high </span><span style="background-color:#fff2f2">ad </span><span style="background-color:#ffdada">prices </span><span style="background-color:#ff7272">-- </span><span style="background-color:#ffb6b6">$ </span><span style="background-color:#ffc0c0">130,000 </span><span style="background-color:#ff7878">for </span><span style="background-color:#ff4242">a </span><span style="background-color:#ff6a6a">four-color </span><span style="background-color:#ffe0e0">page </span><span style="background-color:#ff5e5e">, </span><span style="background-color:#ffc0c0">vs. </span><span style="background-color:#ffb8b8">$ </span><span style="background-color:#ffc6c6">47,000 </span><span style="background-color:#ffc6c6">for </span><span style="background-color:#ff6262">the </span><span style="background-color:#ffd6d6">Smithsonian </span><span style="background-color:#ff3a3a">, </span><span style="background-color:#ff1010">a </span><span style="background-color:#ffe8e8">comparable </span><span style="background-color:#ffa2a2">publication </span><span style="background-color:#ff5858">with </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff1a1a">far </span><span style="background-color:#ffe0e0">smaller </span><span style="background-color:#ffd0d0">circulation </span><span style="background-color:#ffe2e2">. </span><br><br>Sentence index: 5407<br><span style="background-color:#ffeeee">`` </span><span style="background-color:#ffb0b0">This </span><span style="background-color:#ff5858">is </span><span style="background-color:#ff6262">common </span><span style="background-color:#ffacac">with </span><span style="background-color:#ff1616" ...
# Network: openai_transformer_-1, neuron  507
# <code>Sentence index: 255<br><span style="background-color:#f0f0ff">Also </span><span style="background-color:#fcfcff">, </span><span style="background-color:#fffafa">Richard </span><span style="background-color:#ffeaea">A. </span><span style="background-color:#ffe8e8">Barkley </span><span style="background-color:#fefeff">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff0000">former </span><span style="background-color:#ff0000">marketing </span><span style="background-color:#ffdcdc">executive </span><span style="background-color:#f4f4ff">with </span><span style="background-color:#ff8888">FMC </span><span style="background-color:#f4f4ff">Corp. </span><span style="background-color:#f2f2ff">, </span><span style="background-color:#f0f0ff">was </span><span style="background-color:#fffcfc">appointed </span><span style="background-color:#ffb8b8">president </span><span style="background-color:#fefeff">of </span><span style="background-color:#ff5a5a">Continental </span><span style="background-color:#ff0000">Container </span><span style="background-color:#ffbaba">Systems </span><span style="background-color:#fffcfc">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#ffc2c2">producer </span><span style="background-color:#fff4f4">of </span><span style="background-color:#f4f4ff">can </span><span style="background-color:#ff8282">closing </span><span style="background-color:#ff7474">machinery </span><span style="background-color:#fefeff">that </span><span style="background-color:#fffcfc">Figgie </span><span style="background-color:#ffe6e6">acquired </span><span style="background-color:#ffeaea">late </span><span style="background-color:#ff6c6c">last </span><span style="background-color:#ffa6a6">year </span><span style="background-color:#eeeeff">. </span><br><br>Sentence index: 3097<br><span style="background-color:#eeeeff">Perhaps </span><span style="background-color:#ff0000">the </span><span style="background-color:#ff0000">biggest </span><span style="background-color:#f0f0ff">of </span><span style="background-color:#ffc0c0">those </span><span style="background-color:#fefeff">factors </span><span style="background-color:#d6d6ff">is </span><span style="background-color:#ff0000">its </span><span style="background-color:#ff0000">high </span><span style="background-color:#ff1a1a">ad </span><span style="background-color:#ffa4a4">prices </span><span style="background-color:#fffefe">-- </span><span style="background-color:#ffcaca">$ </span><span style="background-color:#ff9a9a">130,000 </span><span style="background-color:#dadaff">for </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff3434">four-color </span><span style="background-color:#ffcaca">page </span><span style="background-color:#f8f8ff">, </span><span style="background-color:#fff4f4">vs. </span><span style="background-color:#fff8f8">$ </span><span style="background-color:#ffa0a0">47,000 </span><span style="background-color:#f0f0ff">for </span><span style="background-color:#ff0000">the </span><span style="background-color:#ff4a4a">Smithsonian </span><span style="background-color:#fff2f2">, </span><span style="background-color:#ff4646">a </span><span style="background-color:#ff2020">comparable </span><span style="background-color:#ffe4e4">publication </span><span style="background-color:#ececff">with </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff7878">far </span><span style="background-color:#ff0000">smaller </span><span style="background-color:#ff7676">circulation </span><span style="background-color:#e8e8ff">. </span><br><br>Sentence index: 5407<br><span style="background-color:#fffefe">`` </span><span style="background-color:#ffe0e0">This </span><span style="background-color:#e6e6ff">is </span><span style="background-color:#ff3434">common </span><span style="background-color:#fefeff">with </span><span style="background-color:#ff0000" ...
# Network: bert_base_cased_-1, neuron   98
# <code>Sentence index: 255<br><span style="background-color:#ff0000">Also </span><span style="background-color:#f0f0ff">, </span><span style="background-color:#ffeeee">Richard </span><span style="background-color:#9e9eff">A. </span><span style="background-color:#bebeff">Barkley </span><span style="background-color:#c6c6ff">, </span><span style="background-color:#c0c0ff">a </span><span style="background-color:#d4d4ff">former </span><span style="background-color:#d2d2ff">marketing </span><span style="background-color:#b6b6ff">executive </span><span style="background-color:#fafaff">with </span><span style="background-color:#e0e0ff">FMC </span><span style="background-color:#eaeaff">Corp. </span><span style="background-color:#d2d2ff">, </span><span style="background-color:#e8e8ff">was </span><span style="background-color:#e0e0ff">appointed </span><span style="background-color:#ccccff">president </span><span style="background-color:#ececff">of </span><span style="background-color:#fafaff">Continental </span><span style="background-color:#b2b2ff">Container </span><span style="background-color:#d6d6ff">Systems </span><span style="background-color:#ececff">, </span><span style="background-color:#dedeff">a </span><span style="background-color:#c8c8ff">producer </span><span style="background-color:#c2c2ff">of </span><span style="background-color:#dadaff">can </span><span style="background-color:#eaeaff">closing </span><span style="background-color:#e6e6ff">machinery </span><span style="background-color:#dadaff">that </span><span style="background-color:#eaeaff">Figgie </span><span style="background-color:#e2e2ff">acquired </span><span style="background-color:#eeeeff">late </span><span style="background-color:#eeeeff">last </span><span style="background-color:#bebeff">year </span><span style="background-color:#aaaaff">. </span><br><br>Sentence index: 3097<br><span style="background-color:#ff0000">Perhaps </span><span style="background-color:#cacaff">the </span><span style="background-color:#d4d4ff">biggest </span><span style="background-color:#9c9cff">of </span><span style="background-color:#f0f0ff">those </span><span style="background-color:#fefeff">factors </span><span style="background-color:#e0e0ff">is </span><span style="background-color:#f2f2ff">its </span><span style="background-color:#fcfcff">high </span><span style="background-color:#f0f0ff">ad </span><span style="background-color:#ffeeee">prices </span><span style="background-color:#f8f8ff">-- </span><span style="background-color:#eaeaff">$ </span><span style="background-color:#eeeeff">130,000 </span><span style="background-color:#fafaff">for </span><span style="background-color:#ffecec">a </span><span style="background-color:#d0d0ff">four-color </span><span style="background-color:#dcdcff">page </span><span style="background-color:#fff4f4">, </span><span style="background-color:#ffbaba">vs. </span><span style="background-color:#e4e4ff">$ </span><span style="background-color:#ffe6e6">47,000 </span><span style="background-color:#fffafa">for </span><span style="background-color:#c4c4ff">the </span><span style="background-color:#e2e2ff">Smithsonian </span><span style="background-color:#fefeff">, </span><span style="background-color:#ffecec">a </span><span style="background-color:#ffe8e8">comparable </span><span style="background-color:#babaff">publication </span><span style="background-color:#ffe0e0">with </span><span style="background-color:#fafaff">a </span><span style="background-color:#eaeaff">far </span><span style="background-color:#fffefe">smaller </span><span style="background-color:#c8c8ff">circulation </span><span style="background-color:#d4d4ff">. </span><br><br>Sentence index: 5407<br><span style="background-color:#fff6f6">`` </span><span style="background-color:#ffc2c2">This </span><span style="background-color:#e8e8ff">is </span><span style="background-color:#e0e0ff">common </span><span style="background-color:#f4f4ff">with </span><span style="background-color:#9e9eff" ...
# Network: elmo_original_-1, neuron  774
# <code>Sentence index: 255<br><span style="background-color:#6464ff">Also </span><span style="background-color:#0000ff">, </span><span style="background-color:#ffeeee">Richard </span><span style="background-color:#acacff">A. </span><span style="background-color:#cacaff">Barkley </span><span style="background-color:#5e5eff">, </span><span style="background-color:#ff7878">a </span><span style="background-color:#ff6e6e">former </span><span style="background-color:#ffc4c4">marketing </span><span style="background-color:#dedeff">executive </span><span style="background-color:#d4d4ff">with </span><span style="background-color:#d4d4ff">FMC </span><span style="background-color:#e8e8ff">Corp. </span><span style="background-color:#0000ff">, </span><span style="background-color:#ff4e4e">was </span><span style="background-color:#ffc0c0">appointed </span><span style="background-color:#ffd8d8">president </span><span style="background-color:#3838ff">of </span><span style="background-color:#f2f2ff">Continental </span><span style="background-color:#ffc2c2">Container </span><span style="background-color:#7a7aff">Systems </span><span style="background-color:#0000ff">, </span><span style="background-color:#fff2f2">a </span><span style="background-color:#babaff">producer </span><span style="background-color:#0000ff">of </span><span style="background-color:#9292ff">can </span><span style="background-color:#dadaff">closing </span><span style="background-color:#ffb8b8">machinery </span><span style="background-color:#e2e2ff">that </span><span style="background-color:#7272ff">Figgie </span><span style="background-color:#ffdcdc">acquired </span><span style="background-color:#3c3cff">late </span><span style="background-color:#1e1eff">last </span><span style="background-color:#8c8cff">year </span><span style="background-color:#0000ff">. </span><br><br>Sentence index: 3097<br><span style="background-color:#fcfcff">Perhaps </span><span style="background-color:#ffcece">the </span><span style="background-color:#ff8686">biggest </span><span style="background-color:#ffe0e0">of </span><span style="background-color:#a2a2ff">those </span><span style="background-color:#acacff">factors </span><span style="background-color:#eaeaff">is </span><span style="background-color:#dcdcff">its </span><span style="background-color:#fefeff">high </span><span style="background-color:#ffc4c4">ad </span><span style="background-color:#ff7272">prices </span><span style="background-color:#0808ff">-- </span><span style="background-color:#ff8080">$ </span><span style="background-color:#ff3e3e">130,000 </span><span style="background-color:#ff7474">for </span><span style="background-color:#ffeaea">a </span><span style="background-color:#e2e2ff">four-color </span><span style="background-color:#9494ff">page </span><span style="background-color:#0000ff">, </span><span style="background-color:#fff6f6">vs. </span><span style="background-color:#ff8282">$ </span><span style="background-color:#ff2828">47,000 </span><span style="background-color:#ff9c9c">for </span><span style="background-color:#ffe2e2">the </span><span style="background-color:#ffe0e0">Smithsonian </span><span style="background-color:#0000ff">, </span><span style="background-color:#ffd4d4">a </span><span style="background-color:#fefeff">comparable </span><span style="background-color:#fff0f0">publication </span><span style="background-color:#fffefe">with </span><span style="background-color:#ffaeae">a </span><span style="background-color:#ffd6d6">far </span><span style="background-color:#ffbcbc">smaller </span><span style="background-color:#fff0f0">circulation </span><span style="background-color:#0000ff">. </span><br><br>Sentence index: 5407<br><span style="background-color:#ff7c7c">`` </span><span style="background-color:#ffc4c4">This </span><span style="background-color:#e2e2ff">is </span><span style="background-color:#ff3636">common </span><span style="background-color:#ffaaaa">with </span><span style="background-color:#ffd6d6" ...
# Network: calypso_transformer_6_512_base_-1, neuron  948
# <code>Sentence index: 255<br><span style="background-color:#2c2cff">Also </span><span style="background-color:#babaff">, </span><span style="background-color:#ff7e7e">Richard </span><span style="background-color:#5e5eff">A. </span><span style="background-color:#a2a2ff">Barkley </span><span style="background-color:#d8d8ff">, </span><span style="background-color:#ff0808">a </span><span style="background-color:#ff0000">former </span><span style="background-color:#ff0000">marketing </span><span style="background-color:#ff0000">executive </span><span style="background-color:#ff0606">with </span><span style="background-color:#ff9292">FMC </span><span style="background-color:#9090ff">Corp. </span><span style="background-color:#ffe4e4">, </span><span style="background-color:#a8a8ff">was </span><span style="background-color:#ffa8a8">appointed </span><span style="background-color:#ff0000">president </span><span style="background-color:#ff3a3a">of </span><span style="background-color:#ff7272">Continental </span><span style="background-color:#7a7aff">Container </span><span style="background-color:#5454ff">Systems </span><span style="background-color:#9c9cff">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff0000">producer </span><span style="background-color:#ff0000">of </span><span style="background-color:#ff2020">can </span><span style="background-color:#ff1010">closing </span><span style="background-color:#ff4646">machinery </span><span style="background-color:#ffe2e2">that </span><span style="background-color:#eeeeff">Figgie </span><span style="background-color:#ff8484">acquired </span><span style="background-color:#ff0000">late </span><span style="background-color:#ff0000">last </span><span style="background-color:#ff0000">year </span><span style="background-color:#ff0000">. </span><br><br>Sentence index: 3097<br><span style="background-color:#6262ff">Perhaps </span><span style="background-color:#a2a2ff">the </span><span style="background-color:#ff1818">biggest </span><span style="background-color:#ff0000">of </span><span style="background-color:#ff0000">those </span><span style="background-color:#ff0000">factors </span><span style="background-color:#ff0000">is </span><span style="background-color:#ff0000">its </span><span style="background-color:#ff0000">high </span><span style="background-color:#ff0000">ad </span><span style="background-color:#ff0000">prices </span><span style="background-color:#ff0000">-- </span><span style="background-color:#ff0404">$ </span><span style="background-color:#ff0000">130,000 </span><span style="background-color:#ff0000">for </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff9292">four-color </span><span style="background-color:#ff5454">page </span><span style="background-color:#ff3a3a">, </span><span style="background-color:#ff0000">vs. </span><span style="background-color:#ff0000">$ </span><span style="background-color:#ff0000">47,000 </span><span style="background-color:#ff5c5c">for </span><span style="background-color:#ff0000">the </span><span style="background-color:#ffc2c2">Smithsonian </span><span style="background-color:#a8a8ff">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff0000">comparable </span><span style="background-color:#ff0000">publication </span><span style="background-color:#ff0a0a">with </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff0000">far </span><span style="background-color:#ff0000">smaller </span><span style="background-color:#ff0000">circulation </span><span style="background-color:#ff0000">. </span><br><br>Sentence index: 5407<br><span style="background-color:#3636ff">`` </span><span style="background-color:#e6e6ff">This </span><span style="background-color:#ff1a1a">is </span><span style="background-color:#ff0000">common </span><span style="background-color:#ff0000">with </span><span style="background-color:#ff0000" ...
# Network: elmo_4x4096_512_-1, neuron  192
# <code>Sentence index: 255<br><span style="background-color:#fff0f0">Also </span><span style="background-color:#eeeeff">, </span><span style="background-color:#ff8888">Richard </span><span style="background-color:#ffcaca">A. </span><span style="background-color:#fafaff">Barkley </span><span style="background-color:#e2e2ff">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff0000">former </span><span style="background-color:#ff0000">marketing </span><span style="background-color:#d6d6ff">executive </span><span style="background-color:#ffeaea">with </span><span style="background-color:#e2e2ff">FMC </span><span style="background-color:#ececff">Corp. </span><span style="background-color:#c6c6ff">, </span><span style="background-color:#d0d0ff">was </span><span style="background-color:#babaff">appointed </span><span style="background-color:#ffd6d6">president </span><span style="background-color:#fffefe">of </span><span style="background-color:#d2d2ff">Continental </span><span style="background-color:#b8b8ff">Container </span><span style="background-color:#ffd6d6">Systems </span><span style="background-color:#fcfcff">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#fafaff">producer </span><span style="background-color:#f0f0ff">of </span><span style="background-color:#ffacac">can </span><span style="background-color:#f8f8ff">closing </span><span style="background-color:#ffe2e2">machinery </span><span style="background-color:#ffecec">that </span><span style="background-color:#f8f8ff">Figgie </span><span style="background-color:#ffd6d6">acquired </span><span style="background-color:#dedeff">late </span><span style="background-color:#ffe2e2">last </span><span style="background-color:#fff0f0">year </span><span style="background-color:#d4d4ff">. </span><br><br>Sentence index: 3097<br><span style="background-color:#dedeff">Perhaps </span><span style="background-color:#ff0000">the </span><span style="background-color:#ff0000">biggest </span><span style="background-color:#c4c4ff">of </span><span style="background-color:#ff7e7e">those </span><span style="background-color:#eeeeff">factors </span><span style="background-color:#d0d0ff">is </span><span style="background-color:#ff0000">its </span><span style="background-color:#ff0000">high </span><span style="background-color:#ff7474">ad </span><span style="background-color:#ffdede">prices </span><span style="background-color:#eeeeff">-- </span><span style="background-color:#ff9c9c">$ </span><span style="background-color:#fffafa">130,000 </span><span style="background-color:#f4f4ff">for </span><span style="background-color:#ff0000">a </span><span style="background-color:#ffaaaa">four-color </span><span style="background-color:#fff2f2">page </span><span style="background-color:#fffafa">, </span><span style="background-color:#f8f8ff">vs. </span><span style="background-color:#ff8e8e">$ </span><span style="background-color:#d8d8ff">47,000 </span><span style="background-color:#dadaff">for </span><span style="background-color:#ff0000">the </span><span style="background-color:#ffd6d6">Smithsonian </span><span style="background-color:#f2f2ff">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff0000">comparable </span><span style="background-color:#dcdcff">publication </span><span style="background-color:#ffbcbc">with </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff4848">far </span><span style="background-color:#ff0000">smaller </span><span style="background-color:#ffd6d6">circulation </span><span style="background-color:#e2e2ff">. </span><br><br>Sentence index: 5407<br><span style="background-color:#fff6f6">`` </span><span style="background-color:#ff9696">This </span><span style="background-color:#d4d4ff">is </span><span style="background-color:#ffdada">common </span><span style="background-color:#ffd6d6">with </span><span style="background-color:#ff0000" ...
# Network: xlnet_large_cased_-1, neuron  860
# <code>Sentence index: 255<br><span style="background-color:#ff0a0a">Also </span><span style="background-color:#ffcccc">, </span><span style="background-color:#0000ff">Richard </span><span style="background-color:#0000ff">A. </span><span style="background-color:#0000ff">Barkley </span><span style="background-color:#fff4f4">, </span><span style="background-color:#0000ff">a </span><span style="background-color:#0e0eff">former </span><span style="background-color:#0000ff">marketing </span><span style="background-color:#0000ff">executive </span><span style="background-color:#2a2aff">with </span><span style="background-color:#b4b4ff">FMC </span><span style="background-color:#ff7676">Corp. </span><span style="background-color:#ffa0a0">, </span><span style="background-color:#ccccff">was </span><span style="background-color:#0000ff">appointed </span><span style="background-color:#0000ff">president </span><span style="background-color:#0000ff">of </span><span style="background-color:#0000ff">Continental </span><span style="background-color:#0000ff">Container </span><span style="background-color:#0000ff">Systems </span><span style="background-color:#ffaeae">, </span><span style="background-color:#ff8a8a">a </span><span style="background-color:#0000ff">producer </span><span style="background-color:#ffb8b8">of </span><span style="background-color:#0000ff">can </span><span style="background-color:#7e7eff">closing </span><span style="background-color:#0000ff">machinery </span><span style="background-color:#ffb8b8">that </span><span style="background-color:#e8e8ff">Figgie </span><span style="background-color:#9a9aff">acquired </span><span style="background-color:#ff1212">late </span><span style="background-color:#ff9e9e">last </span><span style="background-color:#0000ff">year </span><span style="background-color:#ff3030">. </span><br><br>Sentence index: 3097<br><span style="background-color:#ff6e6e">Perhaps </span><span style="background-color:#ff6868">the </span><span style="background-color:#0000ff">biggest </span><span style="background-color:#9696ff">of </span><span style="background-color:#ff0000">those </span><span style="background-color:#0000ff">factors </span><span style="background-color:#ffcccc">is </span><span style="background-color:#fcfcff">its </span><span style="background-color:#0000ff">high </span><span style="background-color:#0000ff">ad </span><span style="background-color:#c0c0ff">prices </span><span style="background-color:#ff0000">-- </span><span style="background-color:#0000ff">$ </span><span style="background-color:#0000ff">130,000 </span><span style="background-color:#ffc4c4">for </span><span style="background-color:#ffa6a6">a </span><span style="background-color:#0000ff">four-color </span><span style="background-color:#0000ff">page </span><span style="background-color:#ff6c6c">, </span><span style="background-color:#ffa2a2">vs. </span><span style="background-color:#0000ff">$ </span><span style="background-color:#0000ff">47,000 </span><span style="background-color:#ffbebe">for </span><span style="background-color:#ff5c5c">the </span><span style="background-color:#0000ff">Smithsonian </span><span style="background-color:#ff0000">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#0000ff">comparable </span><span style="background-color:#0000ff">publication </span><span style="background-color:#dedeff">with </span><span style="background-color:#b2b2ff">a </span><span style="background-color:#0000ff">far </span><span style="background-color:#0000ff">smaller </span><span style="background-color:#1818ff">circulation </span><span style="background-color:#ff1e1e">. </span><br><br>Sentence index: 5407<br><span style="background-color:#ff0000">`` </span><span style="background-color:#ff0000">This </span><span style="background-color:#ff0000">is </span><span style="background-color:#ffc2c2">common </span><span style="background-color:#f6f6ff">with </span><span style="background-color:#0c0cff" ...

# %% [markdown]
# # Notable neurons

# %%
s_ix_l=[str(i) for i in np.random.choice(5512, (20,))]
visualize_neuron('elmo_4x4096_512_-1', neuron_ix=192, s_ix_l=s_ix_l)
# Out:
# Network: elmo_4x4096_512_-1, neuron  192
# <code>Sentence index: 2046<br><span style="background-color:#fffefe">India </span><span style="background-color:#ff0000">'s </span><span style="background-color:#ffe4e4">Gandhi </span><span style="background-color:#bcbcff">called </span><span style="background-color:#fff4f4">for </span><span style="background-color:#ff0000">parliamentary </span><span style="background-color:#c4c4ff">elections </span><span style="background-color:#ffe0e0">next </span><span style="background-color:#fffefe">month </span><span style="background-color:#fafaff">. </span><br><br>Sentence index: 1871<br><span style="background-color:#f4f4ff">In </span><span style="background-color:#ff0000">a </span><span style="background-color:#ffacac">Securities </span><span style="background-color:#d2d2ff">and </span><span style="background-color:#ff3232">Exchange </span><span style="background-color:#ff0404">Commission </span><span style="background-color:#bebeff">filing </span><span style="background-color:#bcbcff">, </span><span style="background-color:#e2e2ff">BroadBeach </span><span style="background-color:#f6f6ff">said </span><span style="background-color:#fffafa">it </span><span style="background-color:#fff6f6">sold </span><span style="background-color:#ff0000">the </span><span style="background-color:#ff4c4c">101,000 </span><span style="background-color:#ffbcbc">McGill </span><span style="background-color:#e4e4ff">shares </span><span style="background-color:#fff4f4">for </span><span style="background-color:#ff9292">$ </span><span style="background-color:#a8a8ff">7.3 </span><span style="background-color:#f0f0ff">million </span><span style="background-color:#f0f0ff">in </span><span style="background-color:#ff0000">a </span><span style="background-color:#ff0000">private </span><span style="background-color:#f2f2ff">transaction </span><span style="background-color:#fefeff">on </span><span style="background-color:#8c8cff">Oct. </span><span style="background-color:#ffcccc">12 </span><span style="background-color:#dedeff">. </span><br><br>Sentence index: 2496<br><span style="background-color:#ffe4e4">Miami </span><span style="background-color:#ffa4a4">Lakes </span><span style="background-color:#fcfcff">, </span><span style="background-color:#ff6666">Fla </span><span style="background-color:#ffe0e0">. </span><br><br>Sentence index: 99<br><span style="background-color:#ff0000">A </span><span style="background-color:#ff0000">six-month </span><span style="background-color:#ff0000">, </span><span style="background-color:#ff0000">broker-sold </span><span style="background-color:#eaeaff">CD </span><span style="background-color:#d8d8ff">, </span><span style="background-color:#ffdede">for </span><span style="background-color:#ffc6c6">example </span><span style="background-color:#ffeaea">, </span><span style="background-color:#d2d2ff">was </span><span style="background-color:#fffafa">yielding </span><span style="background-color:#ff8282">an </span><span style="background-color:#ff7a7a">average </span><span style="background-color:#e8e8ff">8.09 </span><span style="background-color:#ffb6b6">% </span><span style="background-color:#fffefe">in </span><span style="background-color:#ff0000">the </span><span style="background-color:#ff0000">latest </span><span style="background-color:#eeeeff">week </span><span style="background-color:#fff2f2">, </span><span style="background-color:#ff0000">a </span><span style="background-color:#a6a6ff">fifth </span><span style="background-color:#c0c0ff">of </span><span style="background-color:#ff9e9e">a </span><span style="background-color:#f8f8ff">percentage </span><span style="background-color:#ffcccc">point </span><span style="background-color:#ffb6b6">lower </span><span style="background-color:#d6d6ff">than </span><span style="background-color:#ff0000">the </span><span style="background-color:#ffd4d4">week </span><span style="background-color:#ffcaca">before </span><span style="background-color:#fafaff">. </span><br><br>Sentence index: 2008<br ...
