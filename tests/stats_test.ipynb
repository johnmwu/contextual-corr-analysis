# %%
import pickle

# %%
fname = "/data/sls/temp/johnmwu/contextual-corr-analysis/stats"
with open(fname, 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'mean': {'bert_large_cased': array([[ 0.07546603,  0.23159017,  0.23021792, ...,  0.13802163,
#            0.04392174,  0.19251606],
#          [-0.5285153 ,  0.17394842,  0.35681516, ...,  0.14224322,
#            0.07345963, -0.01436026],
#          [-0.6536851 ,  0.09547115,  0.27739254, ...,  0.03946011,
#           -0.1366935 , -0.04176137],
#          ...,
#          [ 0.23852435,  0.00439512, -0.4210141 , ..., -0.15796337,
#           -0.2316738 , -0.06417692],
#          [ 0.12952535,  0.15945254, -0.38253036, ..., -0.02107585,
#           -0.13640355, -0.05416429],
#          [ 0.10503084,  0.585686  , -0.4632475 , ..., -0.07116503,
#            0.00575563,  0.15792787]], dtype=float32)},
#  'std': {'bert_large_cased': array([[0.50663877, 0.494787  , 0.38212454, ..., 0.316504  , 0.36530402,
#           0.6710351 ],
#          [0.6563406 , 0.6709739 , 0.35150498, ..., 0.43776292, 0.46150035,
#           0.77096534],
# ...
