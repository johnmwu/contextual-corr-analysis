# %% [markdown]
# # Summary
# - Bert's are similar to one another. ELMos are similar to one another
# - No pair of transformers that similar to one another (see CKA and SVCCA similarity) except for two BERTs. More similar to ELMos
# - MaxCorr, MinCorr, LinReg rankings are similar (usu. >0.7 spearman)
# - All models much more correlated than random. Thus, I believe we don't need to worry about the advantage larger models have with linreging to another

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from os.path import basename, dirname
import torch

# %%
# Set `res_d`, `network_l`, `num_neurons_d`
base = "/data/sls/temp/johnmwu/contextual-corr-analysis/results1_"
res_fname = {method : base + method for method in 
                {"maxcorr", "mincorr", "linreg", "svcca", "cka"}}

res_d = {}
res_d["maxcorr"] = json.load(open(res_fname["maxcorr"], "r"))
res_d["mincorr"] = json.load(open(res_fname["mincorr"], "r"))
res_d["linreg"] = json.load(open(res_fname["linreg"], "r"))

network_l = [network for network in res_d["maxcorr"]]

num_neurons_d = {}
for network in network_l:
    num_neurons_d[network] = len(res_d["maxcorr"][network])

num_neurons_d
# Out:
# {'/data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/bert_large_cased/ptb_pos_dev.hdf5': 1024,
#  '/data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/openai_transformer/ptb_pos_dev.hdf5': 768,
#  '/data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/bert_base_cased/ptb_pos_dev.hdf5': 768,
#  '/data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/elmo_original/ptb_pos_dev.hdf5': 1024,
#  '/data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/calypso_transformer_6_512_base/ptb_pos_dev.hdf5': 1024,
#  '/data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/elmo_4x4096_512/ptb_pos_dev.hdf5': 1024}

# %% [markdown]
# # MaxCorr, MinCorr, LinReg

# %% [markdown]
# ### Sorts

# %%
rk_methods = {"maxcorr", "mincorr", "linreg"}

# %%
neuron_sorts = {network: {} for network in network_l}
for network in network_l:
    for method in rk_methods:
        neuron_sorts[network][method] = [neuron[0] for neuron in res_d[method][network]]

# %%
# Set `rk_ar_d`, `rk_df_d`, `spearman_d`
rk_ar_d = {}
rk_df_d = {}
spearman_d = {}
for network in network_l:
    # rk_ar[method_ix, neuron] = rank
    # need to invert the permutation
    rk_ar = np.stack([
            [neuron_sorts[network][method].index(neuron) for neuron in range(len(neuron_sorts[network][method]))]
                      for method in rk_methods
    ]).T
    rk_df = pd.DataFrame(rk_ar, columns=list(rk_methods))
    
    rk_ar_d[network] = rk_ar
    rk_df_d[network] = rk_df
    spearman_d[network] = rk_df.corr()

# %%
for network in network_l:
    print(network)
    print(rk_ar_d[network])
    print(spearman_d[network])
# Out:
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/bert_large_cased/ptb_pos_dev.hdf5
# [[799 644 706]
#  [ 35  32  48]
#  [436 429 589]
#  ...
#  [508 475 325]
#  [904 845 912]
#  [815 799 869]]
#            linreg   mincorr   maxcorr
# linreg   1.000000  0.825473  0.822364
# mincorr  0.825473  1.000000  0.833914
# maxcorr  0.822364  0.833914  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/openai_transformer/ptb_pos_dev.hdf5
# [[ 54  54  62]
#  [728 645 553]
#  [159  67  80]
#  ...
#  [745 704 695]
#  [757 722 760]
#  [358 287 302]]
#            linreg   mincorr   maxcorr
# linreg   1.000000  0.793264  0.807733
# mincorr  0.793264  1.000000  0.763334
# maxcorr  0.807733  0.763334  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/bert_base_cased/ptb_pos_dev.hdf5
# [[579 510 344]
#  [196 376 341]
#  [383 571 409]
#  ...
#  [689 649 350]
#  [151 215 380]
#  [272  56 148]]
#            linreg   mincorr   maxcorr
# linreg   1.000000  0.777040  0.769092
# mincorr  0.777040  1.000000  0.756867
# maxcorr  0.769092  0.756867  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/elmo_original/ptb_pos_dev.hdf5
# [[251 651  63]
#  [704 733 888]
#  [381 182 369]
#  ...
#  [179 120 119]
#  [834 871 679]
#  [495 753 260]]
#            linreg   mincorr   maxcorr
# linreg   1.000000  0.753838  0.698621
# mincorr  0.753838  1.000000  0.719712
# maxcorr  0.698621  0.719712  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/calypso_transformer_6_512_base/ptb_pos_dev.hdf5
# [[ 23  42  29]
#  [846 496 731]
#  [488 483 689]
#  ...
#  [871 371 435]
#  [351 478 185]
#  [925 827 712]]
#            linreg   mincorr   maxcorr
# linreg   1.000000  0.618887  0.561620
# mincorr  0.618887  1.000000  0.766353
# maxcorr  0.561620  0.766353  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/elmo_4x4096_512/ptb_pos_dev.hdf5
# [[  8  14  14]
#  [335 545 788]
#  [ 25 124   8]
#  ...
#  [564  62 307]
#  [623 519 450]
#  [148 214 104]]
#            linreg   mincorr   maxcorr
# linreg   1.000000  0.755254  0.708093
# mincorr  0.755254  1.000000  0.727291
# maxcorr  0.708093  0.727291  1.000000

# %% [markdown]
# ### Distributions

# %%
for network in network_l:
    print("\n\n" + network + ":")
    for method in rk_methods:
        print("\n" + method)
        corr_ar = np.stack([
            list(notated_neuron[1].values())
            for notated_neuron in res_d[method][network]
        ])
        corr_df = pd.DataFrame(np.abs(corr_ar), 
                               columns=[basename(dirname(net)) 
                                        for net in network_l if net != network])
        
        print("\nmaxcounts")
        print(corr_df.idxmax(axis=1).value_counts())
        
        print("\nmincounts")
        print(corr_df.idxmin(axis=1).value_counts())
        
        print("\ncorr_df_pctl")
        corr_df_pctl = pd.DataFrame()
        corr_df_pctl["max"] = corr_df.max(axis=1)
        corr_df_pctl["min"] = corr_df.min(axis=1)
        corr_df_pctl["med"] = corr_df.median(axis=1)
        print(corr_df_pctl.rank().corr()) # spearman
        
        corr_df.plot()
        plt.xlabel("neuron (sorted order)")
        plt.ylabel("correlation")
        plt.show()
        
        plt.hist(corr_ar.ravel(), bins=100)
        plt.xlabel("correlation")
        plt.ylabel("count")
        plt.show()
# Out:
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/bert_large_cased/ptb_pos_dev.hdf5:
#
# linreg
#
# maxcounts
# bert_base_cased    1024
# dtype: int64
#
# mincounts
# openai_transformer    1024
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.966028  0.972692
# min  0.966028  1.000000  0.979225
# med  0.972692  0.979225  1.000000
# mincorr
#
# maxcounts
# bert_base_cased                   659
# openai_transformer                124
# calypso_transformer_6_512_base     88
# elmo_4x4096_512                    78
# elmo_original                      75
# dtype: int64
#
# mincounts
# openai_transformer                325
# calypso_transformer_6_512_base    279
# elmo_4x4096_512                   199
# elmo_original                     156
# bert_base_cased                    65
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.833914  0.886658
# min  0.833914  1.000000  0.933785
# med  0.886658  0.933785  1.000000
# maxcorr
#
# maxcounts
# bert_base_cased                   659
# openai_transformer                124
# calypso_transformer_6_512_base     88
# elmo_4x4096_512                    78
# elmo_original                      75
# dtype: int64
#
# mincounts
# openai_transformer                325
# calypso_transformer_6_512_base    279
# elmo_4x4096_512                   199
# elmo_original                     156
# bert_base_cased                    65
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.833914  0.886658
# min  0.833914  1.000000  0.933785
# med  0.886658  0.933785  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/openai_transformer/ptb_pos_dev.hdf5:
#
# linreg
#
# maxcounts
# elmo_original                     416
# calypso_transformer_6_512_base    188
# elmo_4x4096_512                   164
# dtype: int64
#
# mincounts
# bert_large_cased    759
# bert_base_cased       9
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.960673  0.996766
# min  0.960673  1.000000  0.959002
# med  0.996766  0.959002  1.000000
# mincorr
#
# maxcounts
# calypso_transformer_6_512_base    270
# elmo_4x4096_512                   261
# elmo_original                     210
# bert_base_cased                    17
# bert_large_cased                   10
# dtype: int64
#
# mincounts
# bert_base_cased                   382
# bert_large_cased                  354
# calypso_transformer_6_512_base     13
# elmo_4x4096_512                    11
# elmo_original                       8
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.763334  0.930568
# min  0.763334  1.000000  0.798539
# med  0.930568  0.798539  1.000000
# maxcorr
#
# maxcounts
# calypso_transformer_6_512_base    270
# elmo_4x4096_512                   261
# elmo_original                     210
# bert_base_cased                    17
# bert_large_cased                   10
# dtype: int64
#
# mincounts
# bert_base_cased                   382
# bert_large_cased                  354
# calypso_transformer_6_512_base     13
# elmo_4x4096_512                    11
# elmo_original                       8
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.763334  0.930568
# min  0.763334  1.000000  0.798539
# med  0.930568  0.798539  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/bert_base_cased/ptb_pos_dev.hdf5:
#
# linreg
#
# maxcounts
# bert_large_cased    768
# dtype: int64
#
# mincounts
# openai_transformer    768
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.933737  0.946542
# min  0.933737  1.000000  0.971418
# med  0.946542  0.971418  1.000000
# mincorr
#
# maxcounts
# bert_large_cased                  489
# elmo_4x4096_512                    85
# openai_transformer                 79
# calypso_transformer_6_512_base     63
# elmo_original                      52
# dtype: int64
#
# mincounts
# openai_transformer                296
# calypso_transformer_6_512_base    171
# elmo_4x4096_512                   153
# elmo_original                     111
# bert_large_cased                   37
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.756867  0.828793
# min  0.756867  1.000000  0.902188
# med  0.828793  0.902188  1.000000
# maxcorr
#
# maxcounts
# bert_large_cased                  489
# elmo_4x4096_512                    85
# openai_transformer                 79
# calypso_transformer_6_512_base     63
# elmo_original                      52
# dtype: int64
#
# mincounts
# openai_transformer                296
# calypso_transformer_6_512_base    171
# elmo_4x4096_512                   153
# elmo_original                     111
# bert_large_cased                   37
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.756867  0.828793
# min  0.756867  1.000000  0.902188
# med  0.828793  0.902188  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/elmo_original/ptb_pos_dev.hdf5:
#
# linreg
#
# maxcounts
# elmo_4x4096_512                   1023
# calypso_transformer_6_512_base       1
# dtype: int64
#
# mincounts
# openai_transformer    512
# bert_large_cased      452
# bert_base_cased        60
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.683009  0.678210
# min  0.683009  1.000000  0.968331
# med  0.678210  0.968331  1.000000
# mincorr
#
# maxcounts
# elmo_4x4096_512                   550
# calypso_transformer_6_512_base    351
# openai_transformer                 81
# bert_base_cased                    40
# bert_large_cased                    2
# dtype: int64
#
# mincounts
# bert_large_cased                  373
# bert_base_cased                   357
# openai_transformer                277
# calypso_transformer_6_512_base     15
# elmo_4x4096_512                     2
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.719712  0.797515
# min  0.719712  1.000000  0.803773
# med  0.797515  0.803773  1.000000
# maxcorr
#
# maxcounts
# elmo_4x4096_512                   550
# calypso_transformer_6_512_base    351
# openai_transformer                 81
# bert_base_cased                    40
# bert_large_cased                    2
# dtype: int64
#
# mincounts
# bert_large_cased                  373
# bert_base_cased                   357
# openai_transformer                277
# calypso_transformer_6_512_base     15
# elmo_4x4096_512                     2
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.719712  0.797515
# min  0.719712  1.000000  0.803773
# med  0.797515  0.803773  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/calypso_transformer_6_512_base/ptb_pos_dev.hdf5:
#
# linreg
#
# maxcounts
# elmo_4x4096_512    506
# elmo_original      491
# bert_base_cased     27
# dtype: int64
#
# mincounts
# openai_transformer    537
# bert_large_cased      475
# bert_base_cased         9
# elmo_4x4096_512         3
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.272225  0.456933
# min  0.272225  1.000000  0.936766
# med  0.456933  0.936766  1.000000
# mincorr
#
# maxcounts
# elmo_4x4096_512       375
# elmo_original         357
# bert_base_cased       135
# openai_transformer    116
# bert_large_cased       41
# dtype: int64
#
# mincounts
# bert_large_cased      368
# openai_transformer    342
# bert_base_cased       298
# elmo_original          10
# elmo_4x4096_512         6
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.766353  0.880929
# min  0.766353  1.000000  0.808401
# med  0.880929  0.808401  1.000000
# maxcorr
#
# maxcounts
# elmo_4x4096_512       375
# elmo_original         357
# bert_base_cased       135
# openai_transformer    116
# bert_large_cased       41
# dtype: int64
#
# mincounts
# bert_large_cased      368
# openai_transformer    342
# bert_base_cased       298
# elmo_original          10
# elmo_4x4096_512         6
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.766353  0.880929
# min  0.766353  1.000000  0.808401
# med  0.880929  0.808401  1.000000
# /data/sls/temp/belinkov/contextual-corr-analysis/contextualizers/elmo_4x4096_512/ptb_pos_dev.hdf5:
#
# linreg
#
# maxcounts
# elmo_original    1024
# dtype: int64
#
# mincounts
# openai_transformer    512
# bert_large_cased      420
# bert_base_cased        92
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.672428  0.655216
# min  0.672428  1.000000  0.963284
# med  0.655216  0.963284  1.000000
# mincorr
#
# maxcounts
# elmo_original                     517
# calypso_transformer_6_512_base    359
# openai_transformer                 95
# bert_base_cased                    50
# bert_large_cased                    3
# dtype: int64
#
# mincounts
# bert_large_cased                  391
# bert_base_cased                   344
# openai_transformer                282
# calypso_transformer_6_512_base      6
# elmo_original                       1
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.727291  0.784406
# min  0.727291  1.000000  0.786673
# med  0.784406  0.786673  1.000000
# maxcorr
#
# maxcounts
# elmo_original                     517
# calypso_transformer_6_512_base    359
# openai_transformer                 95
# bert_base_cased                    50
# bert_large_cased                    3
# dtype: int64
#
# mincounts
# bert_large_cased                  391
# bert_base_cased                   344
# openai_transformer                282
# calypso_transformer_6_512_base      6
# elmo_original                       1
# dtype: int64
#
# corr_df_pctl
#           max       min       med
# max  1.000000  0.727291  0.784406
# min  0.727291  1.000000  0.786673
# med  0.784406  0.786673  1.000000

# %% [markdown]
# # CKA

# %%
cka_d = torch.load(res_fname["cka"])

# %%
df = pd.DataFrame(cka_d)
df = df.rename(lambda s: basename(dirname(s)))
df = df.rename(lambda s: basename(dirname(s)), axis=1)
df
# Out:
#                                 bert_large_cased  openai_transformer  \
# bert_base_cased                         0.601784            0.307381
# bert_large_cased                             NaN            0.260449
# calypso_transformer_6_512_base          0.287108            0.363168
# elmo_4x4096_512                         0.385873            0.571887
# elmo_original                           0.384842            0.570135
# openai_transformer                      0.260449                 NaN
#
#                                 bert_base_cased  elmo_original  \
# bert_base_cased                             NaN       0.448652
# bert_large_cased                       0.601784       0.384843
# calypso_transformer_6_512_base         0.343199       0.540479
# elmo_4x4096_512                        0.449094       0.890262
# elmo_original                          0.448652            NaN
# openai_transformer                     0.307380       0.570136
#
#                                 calypso_transformer_6_512_base  \
# bert_base_cased                                       0.343198
# bert_large_cased                                      0.287109
# calypso_transformer_6_512_base                             NaN
# elmo_4x4096_512                                       0.540884
# elmo_original                                         0.540479
# openai_transformer                                    0.363168
#
#                                 elmo_4x4096_512
# bert_base_cased                        0.449093
# bert_large_cased                       0.385873
# calypso_transformer_6_512_base         0.540885
# elmo_4x4096_512                             NaN
# elmo_original                          0.890259
# openai_transformer                     0.571889

# %%
df.rank(ascending=False)
# Out:
#                                 bert_large_cased  openai_transformer  \
# bert_base_cased                              1.0                 4.0
# bert_large_cased                             NaN                 5.0
# calypso_transformer_6_512_base               4.0                 3.0
# elmo_4x4096_512                              2.0                 1.0
# elmo_original                                3.0                 2.0
# openai_transformer                           5.0                 NaN
#
#                                 bert_base_cased  elmo_original  \
# bert_base_cased                             NaN            4.0
# bert_large_cased                            1.0            5.0
# calypso_transformer_6_512_base              4.0            3.0
# elmo_4x4096_512                             2.0            1.0
# elmo_original                               3.0            NaN
# openai_transformer                          5.0            2.0
#
#                                 calypso_transformer_6_512_base  \
# bert_base_cased                                            4.0
# bert_large_cased                                           5.0
# calypso_transformer_6_512_base                             NaN
# elmo_4x4096_512                                            1.0
# elmo_original                                              2.0
# openai_transformer                                         3.0
#
#                                 elmo_4x4096_512
# bert_base_cased                             4.0
# bert_large_cased                            5.0
# calypso_transformer_6_512_base              3.0
# elmo_4x4096_512                             NaN
# elmo_original                               1.0
# openai_transformer                          2.0

# %%
df.mean()
# Out:
# bert_large_cased                  0.384011
# openai_transformer                0.414604
# bert_base_cased                   0.430022
# elmo_original                     0.566874
# calypso_transformer_6_512_base    0.414968
# elmo_4x4096_512                   0.567600
# dtype: float64

# %%
df.min()
# Out:
# bert_large_cased                  0.260449
# openai_transformer                0.260449
# bert_base_cased                   0.307380
# elmo_original                     0.384843
# calypso_transformer_6_512_base    0.287109
# elmo_4x4096_512                   0.385873
# dtype: float64

# %% [markdown]
# # SVCCA

# %%
svcca_d = torch.load(res_fname["svcca"])

# %%
corrs, similarities = svcca_d['corrs'], svcca_d['similarities']

# %%
sim_df = pd.DataFrame(similarities)
sim_df = sim_df.rename(lambda s: basename(dirname(s)), axis=0)
sim_df = sim_df.rename(lambda s: basename(dirname(s)), axis=1)
sim_df
# Out:
#                                 bert_large_cased  openai_transformer  \
# bert_base_cased                         0.431474            0.281936
# bert_large_cased                             NaN            0.291185
# calypso_transformer_6_512_base          0.295222            0.365994
# elmo_4x4096_512                         0.286701            0.365158
# elmo_original                           0.290036            0.367776
# openai_transformer                      0.291185                 NaN
#
#                                 bert_base_cased  elmo_original  \
# bert_base_cased                             NaN       0.349747
# bert_large_cased                       0.431474       0.290036
# calypso_transformer_6_512_base         0.360407       0.521415
# elmo_4x4096_512                        0.343010       0.556058
# elmo_original                          0.349747            NaN
# openai_transformer                     0.281936       0.367776
#
#                                 calypso_transformer_6_512_base  \
# bert_base_cased                                       0.360407
# bert_large_cased                                      0.295222
# calypso_transformer_6_512_base                             NaN
# elmo_4x4096_512                                       0.522367
# elmo_original                                         0.521415
# openai_transformer                                    0.365994
#
#                                 elmo_4x4096_512
# bert_base_cased                        0.343010
# bert_large_cased                       0.286701
# calypso_transformer_6_512_base         0.522367
# elmo_4x4096_512                             NaN
# elmo_original                          0.556058
# openai_transformer                     0.365158

# %%
sim_df.rank(ascending=False)
# Out:
#                                 bert_large_cased  openai_transformer  \
# bert_base_cased                              1.0                 5.0
# bert_large_cased                             NaN                 4.0
# calypso_transformer_6_512_base               2.0                 2.0
# elmo_4x4096_512                              5.0                 3.0
# elmo_original                                4.0                 1.0
# openai_transformer                           3.0                 NaN
#
#                                 bert_base_cased  elmo_original  \
# bert_base_cased                             NaN            4.0
# bert_large_cased                            1.0            5.0
# calypso_transformer_6_512_base              2.0            2.0
# elmo_4x4096_512                             4.0            1.0
# elmo_original                               3.0            NaN
# openai_transformer                          5.0            3.0
#
#                                 calypso_transformer_6_512_base  \
# bert_base_cased                                            4.0
# bert_large_cased                                           5.0
# calypso_transformer_6_512_base                             NaN
# elmo_4x4096_512                                            1.0
# elmo_original                                              2.0
# openai_transformer                                         3.0
#
#                                 elmo_4x4096_512
# bert_base_cased                             4.0
# bert_large_cased                            5.0
# calypso_transformer_6_512_base              2.0
# elmo_4x4096_512                             NaN
# elmo_original                               1.0
# openai_transformer                          3.0

# %%
corrs_df = pd.DataFrame(corrs)
corrs_df = corrs_df.rename(lambda s: basename(dirname(s)), axis=0)
corrs_df = corrs_df.rename(lambda s: basename(dirname(s)), axis=1)
corrs_df
# Out:
#                                                                  bert_large_cased  \
# bert_base_cased                 [tensor(0.9803), tensor(0.9689), tensor(0.9639...
# bert_large_cased                                                              NaN
# calypso_transformer_6_512_base  [tensor(0.9681), tensor(0.9608), tensor(0.9408...
# elmo_4x4096_512                 [tensor(0.9755), tensor(0.9485), tensor(0.9409...
# elmo_original                   [tensor(0.9758), tensor(0.9494), tensor(0.9425...
# openai_transformer              [tensor(0.9358), tensor(0.9330), tensor(0.9187...
#
#                                                                openai_transformer  \
# bert_base_cased                 [tensor(0.9497), tensor(0.9438), tensor(0.9302...
# bert_large_cased                [tensor(0.9358), tensor(0.9330), tensor(0.9187...
# calypso_transformer_6_512_base  [tensor(0.9596), tensor(0.9571), tensor(0.9513...
# elmo_4x4096_512                 [tensor(0.9701), tensor(0.9688), tensor(0.9637...
# elmo_original                   [tensor(0.9719), tensor(0.9681), tensor(0.9627...
# openai_transformer                                                            NaN
#
#                                                                   bert_base_cased  \
# bert_base_cased                                                               NaN
# bert_large_cased                [tensor(0.9803), tensor(0.9689), tensor(0.9639...
# calypso_transformer_6_512_base  [tensor(0.9685), tensor(0.9666), tensor(0.9507...
# elmo_4x4096_512                 [tensor(0.9751), tensor(0.9598), tensor(0.9513...
# elmo_original                   [tensor(0.9758), tensor(0.9612), tensor(0.9540...
# openai_transformer              [tensor(0.9497), tensor(0.9438), tensor(0.9302...
#
#                                                                     elmo_original  \
# bert_base_cased                 [tensor(0.9758), tensor(0.9612), tensor(0.9540...
# bert_large_cased                [tensor(0.9758), tensor(0.9494), tensor(0.9425...
# calypso_transformer_6_512_base  [tensor(0.9877), tensor(0.9816), tensor(0.9807...
# elmo_4x4096_512                 [tensor(0.9932), tensor(0.9907), tensor(0.9898...
# elmo_original                                                                 NaN
# openai_transformer              [tensor(0.9719), tensor(0.9681), tensor(0.9627...
#
#                                                    calypso_transformer_6_512_base  \
# bert_base_cased                 [tensor(0.9685), tensor(0.9666), tensor(0.9507...
# bert_large_cased                [tensor(0.9681), tensor(0.9608), tensor(0.9408...
# calypso_transformer_6_512_base                                                NaN
# elmo_4x4096_512                 [tensor(0.9880), tensor(0.9820), tensor(0.9812...
# elmo_original                   [tensor(0.9877), tensor(0.9816), tensor(0.9807...
# openai_transformer              [tensor(0.9596), tensor(0.9571), tensor(0.9513...
#
#                                                                   elmo_4x4096_512
# bert_base_cased                 [tensor(0.9751), tensor(0.9598), tensor(0.9513...
# bert_large_cased                [tensor(0.9755), tensor(0.9485), tensor(0.9409...
# calypso_transformer_6_512_base  [tensor(0.9880), tensor(0.9820), tensor(0.9812...
# elmo_4x4096_512                                                               NaN
# elmo_original                   [tensor(0.9932), tensor(0.9907), tensor(0.9898...
# openai_transformer              [tensor(0.9701), tensor(0.9688), tensor(0.9637...

# %%
maxcorrs_df = corrs_df.applymap(lambda t: float('nan') if type(t) is float else t.max().item())
maxcorrs_df
# Out:
#                                 bert_large_cased  openai_transformer  \
# bert_base_cased                         0.980304            0.949735
# bert_large_cased                             NaN            0.935789
# calypso_transformer_6_512_base          0.968142            0.959553
# elmo_4x4096_512                         0.975461            0.970074
# elmo_original                           0.975797            0.971899
# openai_transformer                      0.935789                 NaN
#
#                                 bert_base_cased  elmo_original  \
# bert_base_cased                             NaN       0.975784
# bert_large_cased                       0.980304       0.975797
# calypso_transformer_6_512_base         0.968456       0.987678
# elmo_4x4096_512                        0.975090       0.993198
# elmo_original                          0.975784            NaN
# openai_transformer                     0.949735       0.971899
#
#                                 calypso_transformer_6_512_base  \
# bert_base_cased                                       0.968456
# bert_large_cased                                      0.968142
# calypso_transformer_6_512_base                             NaN
# elmo_4x4096_512                                       0.987985
# elmo_original                                         0.987678
# openai_transformer                                    0.959553
#
#                                 elmo_4x4096_512
# bert_base_cased                        0.975090
# bert_large_cased                       0.975461
# calypso_transformer_6_512_base         0.987985
# elmo_4x4096_512                             NaN
# elmo_original                          0.993198
# openai_transformer                     0.970074

# %%
maxcorrs_df.rank(ascending=False)
# Out:
#                                 bert_large_cased  openai_transformer  \
# bert_base_cased                              1.0                 4.0
# bert_large_cased                             NaN                 5.0
# calypso_transformer_6_512_base               4.0                 3.0
# elmo_4x4096_512                              3.0                 2.0
# elmo_original                                2.0                 1.0
# openai_transformer                           5.0                 NaN
#
#                                 bert_base_cased  elmo_original  \
# bert_base_cased                             NaN            4.0
# bert_large_cased                            1.0            3.0
# calypso_transformer_6_512_base              4.0            2.0
# elmo_4x4096_512                             3.0            1.0
# elmo_original                               2.0            NaN
# openai_transformer                          5.0            5.0
#
#                                 calypso_transformer_6_512_base  \
# bert_base_cased                                            3.0
# bert_large_cased                                           4.0
# calypso_transformer_6_512_base                             NaN
# elmo_4x4096_512                                            1.0
# elmo_original                                              2.0
# openai_transformer                                         5.0
#
#                                 elmo_4x4096_512
# bert_base_cased                             4.0
# bert_large_cased                            3.0
# calypso_transformer_6_512_base              2.0
# elmo_4x4096_512                             NaN
# elmo_original                               1.0
# openai_transformer                          5.0
